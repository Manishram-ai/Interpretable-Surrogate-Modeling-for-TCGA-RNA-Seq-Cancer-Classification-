# %% [markdown]
# #Data process and Import

# %%
import pandas as pd
import numpy as np
import shap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, matthews_corrcoef, roc_auc_score, f1_score
import matplotlib.pyplot as plt




##------------------------------------------------##

df = pd.read_csv('rna_seq_with_column_names.csv')
print("Dataset loaded successfully.")
print("Shape of the dataset:", df.shape)
print("\nFirst 5 rows of the dataset:")
display(df.head())




##----------------------------------------------##


exclude_cols = ['sample', 'tumor_status', 'cancer_type',    "SRY", "ZFY", "RPS4Y1", "RPS4Y2", "AMELY", "TBL1Y", "PCDH11Y",
    "TGIF2LY", "TSPY1", "TSPY2", "USP9Y", "DDX3Y", "UTY", "TB4Y",
    "CYorf15A", "CYorf15B", "EIF1AY", "KDM5D", "XKRY", "HSFY1", "HSFY2",
    "PRY", "PRY2", "RBMY1A1", "DAZ1", "DAZ2", "DAZ3", "DAZ4", "CDY1",
    "CDY2", "VCY1", "VCY2",
    "CYorf15",
    "XIST", "TSIX",
    "TTTY1",
    "TTTY2",
    "TTTY3",
    "TTTY4",
    "TTTY5",
    "TTTY6",
    "TTTY7",
    "TTTY8",
    "TTTY9",
    "TTTY10",
    "TTTY11",
    "TTTY12",
    "TTTY13",
    "TTTY14",
    "TTTY15",]
features = [col for col in df.columns if col not in exclude_cols]
X = df[features]

# Target (y) is the 'cancer_type' column
y = df['cancer_type']

print(f"Number of features (genes): {len(features)}")
print(f"Number of samples: {len(df)}")
print(f"Number of unique cancer types: {y.nunique()}")
print("\nCancer Types Distribution:")
print(y.value_counts())

# Encode string labels to integer labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
class_names = label_encoder.classes_

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("\nData splitting and scaling complete.")
print(f"Training set shape: {X_train_scaled.shape}")
print(f"Test set shape: {X_test_scaled.shape}")







genes_to_exclude = {
    # Y-Chromosome Gene List
    "SRY", "ZFY", "RPS4Y1", "RPS4Y2", "AMELY", "TBL1Y", "PCDH11Y",
    "TGIF2LY", "TSPY1", "TSPY2", "USP9Y", "DDX3Y", "UTY", "TB4Y",
    "CYorf15A", "CYorf15B", "EIF1AY", "KDM5D", "XKRY", "HSFY1", "HSFY2",
    "PRY", "PRY2", "RBMY1A1", "DAZ1", "DAZ2", "DAZ3", "DAZ4", "CDY1",
    "CDY2", "VCY1", "VCY2",
    "CYorf15",
    "XIST", "TSIX",
    "TTTY1",
    "TTTY2",
    "TTTY3",
    "TTTY4",
    "TTTY5",
    "TTTY6",
    "TTTY7",
    "TTTY8",
    "TTTY9",
    "TTTY10",
    "TTTY11",
    "TTTY12",
    "TTTY13",
    "TTTY14",
    "TTTY15",
}
# Out:
# Dataset loaded successfully.
# Shape of the dataset: (8870, 12857)
#
# First 5 rows of the dataset:
#    100133144  100134869  155060  340602  388795  390284  553137  57714  \
# 0       2.03       2.96    7.87    2.03    0.00    1.16     0.0   9.07
# 1       0.00       4.06    7.35    0.00    1.42    2.30     0.0   7.96
# 2       1.98       3.90    7.09    0.88    0.00    1.43     0.0   7.43
# 3       4.09       4.00    8.71    1.54    0.97    0.97     0.0   7.09
# 4       2.71       2.54    8.11    1.15    1.15    1.15     0.0   8.48
#
#    645851  652919  ...  ZSWIM5  ZSWIM6  ZWILCH  ZWINT  ZXDA  ZYG11A    ZYX  \
# 0    4.53    4.43  ...    8.75    9.51    8.03   8.66  6.05    0.69  11.92
# 1    3.61    2.62  ...    5.67    9.13    8.87   7.95  5.45    2.60  13.49
# 2    4.70    0.00  ...    7.79    8.87    9.42   9.39  4.35    5.50  12.31
# 3    5.55    0.00  ...    7.89    9.46    8.79   8.79  5.78    0.00  12.31
# 4    3.43    0.00  ...    6.64    8.66    7.39   6.24  5.03    0.00  12.93
#
#             sample   tumor_status              cancer_type
# 0  TCGA-02-0047-01  Primary Tumor  glioblastoma multiforme
# 1  TCGA-02-0055-01  Primary Tumor  glioblastoma multiforme
# 2  TCGA-02-2483-01  Primary Tumor  glioblastoma multiforme
# 3  TCGA-02-2485-01  Primary Tumor  glioblastoma multiforme
# 4  TCGA-02-2486-01  Primary Tumor  glioblastoma multiforme
#
# [5 rows x 12857 columns]
# Number of features (genes): 12838
# Number of samples: 8870
# Number of unique cancer types: 32
#
# Cancer Types Distribution:
# cancer_type
# breast invasive carcinoma                1211
# kidney clear cell carcinoma               605
# lung adenocarcinoma                       574
# thyroid carcinoma                         564
# head & neck squamous cell carcinoma       564
# lung squamous cell carcinoma              554
# brain lower grade glioma                  516
# prostate adenocarcinoma                   516
# bladder urothelial carcinoma              427
# liver hepatocellular carcinoma            421
# colon adenocarcinoma                      327
# kidney papillary cell carcinoma           322
# cervical & endocervical cancer            308
# sarcoma                                   261
# uterine corpus endometrioid carcinoma     200
# pancreatic adenocarcinoma                 182
# pheochromocytoma & paraganglioma          182
# glioblastoma multiforme                   161
# testicular germ cell tumor                150
# thymoma                                   122
# skin cutaneous melanoma                   104
# rectum adenocarcinoma                     104
# kidney chromophobe                         91
# mesothelioma                               87
# uveal melanoma                             80
# adrenocortical cancer                      79
# uterine carcinosarcoma                     57
# diffuse large B-cell lymphoma              48
# cholangiocarcinoma                         45
# stomach adenocarcinoma                      3
# esophageal carcinoma                        3
# ovarian serous cystadenocarcinoma           2
# Name: count, dtype: int64
#
# Data splitting and scaling complete.
# Training set shape: (7096, 12838)
# Test set shape: (1774, 12838)

# %% [markdown]
# # RF Depth = 5, SHAP

# %%
print("--- Training Random Forest Classifier  with RF Depth = 5 ---")
rf_model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1, max_depth=5)
rf_model.fit(X_train_scaled, y_train)

# Predictions and Probability Predictions
y_pred_rf = rf_model.predict(X_test_scaled)
y_proba_rf = rf_model.predict_proba(X_test_scaled)





##--------------------------------##

#SHAP

# Create SHAP explainer for Random Forest
explainer = shap.TreeExplainer(rf_model)

# Get SHAP values for the first 500 samples of X_test
# Use the scaled test data (X_test_scaled) which was used for training
shap_values = explainer.shap_values(X_test[:500])

print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of SHAP values: {shap_values.shape}")



##---------------------------------##
# PREPROCESS


top_genes_per_class_RF_with_depth = {}
N = 5 # Let's find the top 5 genes for each class

# Iterate through the classes (the third dimension of shap_values)
# shap_values shape: (samples, features, classes)
for i in range(shap_values.shape[2]):
    # Calculate the mean absolute SHAP value for each gene across all samples for the current class
    global_importance = np.mean(np.abs(shap_values[:, :, i]), axis=0)

    # Create a DataFrame for easy sorting
    importance_df = pd.DataFrame({
        'Gene': X.columns,
        'SHAP_Importance': global_importance
    })

    # --- NEW STEP: Filter out the sex-specific genes ---
    filtered_importance_df = importance_df[~importance_df['Gene'].isin(genes_to_exclude)]
    # ----------------------------------------------------

    # Sort by importance and get the top N genes from the *filtered* list
    top_genes = filtered_importance_df.sort_values(by='SHAP_Importance', ascending=False).head(N)

    # Store the results using the actual class name
    class_name = class_names[i]
    top_genes_per_class_RF_with_depth[class_name] = top_genes['Gene'].tolist()

# Print the top genes for all classes
print("Top 5 Tumor-Specific Genes per Class (Sex-Specific Genes Removed):")
for class_name, genes in top_genes_per_class_RF_with_depth.items():
    print(f" {class_name}: {genes}")


#--------------------------------------##


#VIZ THE FEATURES
# Out:
# --- Training Random Forest Classifier  with RF Depth = 5 ---
# Shape of X_test: (1774, 12838)
# Shape of SHAP values: (500, 12838, 32)
# Top 5 Tumor-Specific Genes per Class (Sex-Specific Genes Removed):
#  adrenocortical cancer: ['APOC1', 'SERPINA7', 'CPB1', 'ELOVL5', 'EFHD2']
#  bladder urothelial carcinoma: ['GATA3', 'GINS4', 'SLC45A3', 'EPHB2', 'ASB2']
#  brain lower grade glioma: ['ATP1B2', 'FEZ1', 'APC2', 'TRIM9', 'GPM6B']
#  breast invasive carcinoma: ['PRLR', 'XBP1', 'GATA3', 'ATP1B2', 'NAT1']
#  cervical & endocervical cancer: ['NAT1', 'CYP4Z1', 'IL22RA1', 'ABCC4', 'TTLL13']
#  cholangiocarcinoma: ['APOC1', 'SLC28A1', 'SERPINA7', 'ALDOC', 'PPP1R3B']
#  colon adenocarcinoma: ['FSIP1', 'IGF2BP2', 'PARP11', 'SPDEF', 'NAT1']
#  diffuse large B-cell lymphoma: ['GRIN2D', 'USP49', 'SERPINA7', 'APOC1', 'PLK4']
#  esophageal carcinoma: ['SUSD3', 'APC', 'C5orf49', 'SLC22A6', 'RSRC1']
#  glioblastoma multiforme: ['ATP1B2', 'SOX8', 'FEZ1', 'CSPG5', 'MAP2']
#  head & neck squamous cell carcinoma: ['ANXA2P1', 'CSDAP1', 'ATP5EP2', 'SOX8', 'TCF21']
#  kidney chromophobe: ['SLC22A2', 'PRLR', 'NRL', 'HCN2', 'DEF6']
#  kidney clear cell carcinoma: ['ENPEP', 'FXYD2', 'SLC3A1', 'PAX8', 'SLC28A1']
#  kidney papillary cell carcinoma: ['SLC3A1', 'ENPEP', 'ANXA2P2', 'SLC28A1', 'ORAI3']
#  liver hepatocellular carcinoma: ['MAT1A', 'SLC28A1', 'SLC38A3', 'APOC1', 'PNMA1']
#  lung adenocarcinoma: ['SFTA3', 'SFTPA1', 'PAX8', 'MBIP', 'SKA1']
#  lung squamous cell carcinoma: ['SFTPA1', 'PAX8', 'KRT6A', 'TCF21', 'PCSK6']
#  mesothelioma: ['ESRP1', 'ANXA2P1', 'EFHD1', 'EFHD2', 'C8orf85']
#  ovarian serous cystadenocarcinoma: ['FRK', 'S100A5', 'C2orf43', 'EFHD2', 'C1orf210']
#  pancreatic adenocarcinoma: ['SLC45A3', 'GINS4', 'SLC3A1', 'KIAA1609', 'CD55']
#  pheochromocytoma & paraganglioma: ['RAB3D', 'APC2', 'MANEA', 'GPHN', 'KLK4']
#  prostate adenocarcinoma: ['SLC45A3', 'NKX3-1', 'ZNF761', 'ABCC4', 'STEAP2']
#  rectum adenocarcinoma: ['GPR77', 'MAP2', 'ATP1B2', 'SLC45A3', 'NAT1']
#  sarcoma: ['FBLN1', 'MTSS1L', 'PDE4C', 'PCDHGC3', 'NAT1']
#  skin cutaneous melanoma: ['TMEM117', 'ABCC11', 'ACP6', 'SHOX2', 'EDNRB']
#  stomach adenocarcinoma: ['FGFBP1', 'MSMB', 'ANXA2P1', 'SLC19A1', 'PDE4C']
#  testicular germ cell tumor: ['ZNF552', 'ZNF214', 'DAPK1', 'ZNF761', 'XKR8']
#  thymoma: ['KIF18B', 'TCERG1L', 'EFHD1', 'BVES', 'MNX1']
#  thyroid carcinoma: ['PAX8', 'TG', 'IQCA1', 'IYD', 'AFF1']
#  uterine carcinosarcoma: ['EDA', 'TRPS1', 'TMEM160', 'OSMR', 'PLEKHH2']
#  uterine corpus endometrioid carcinoma: ['PAX8', 'NAT1', 'PREX1', 'LYG1', 'KCND1']
#  uveal melanoma: ['IFT57', 'CCDC30', 'ABCC11', 'ATP1B2', 'EFHD1']

# %%
for class_name, genes_to_plot in top_genes_per_class_RF_with_depth.items():

    # Find the index 'i' corresponding to the current class_name
    # This is needed to slice the correct part of the shap_values array
    i = list(class_names).index(class_name)

    # 1. Get the SHAP values for the current class
    class_shap_values = shap_values[:, :, i]

    # 2. Create the Series of mean absolute SHAP values for ALL features
    # We still need this to look up the values for our selected genes
    feature_importance_series = pd.Series(
        np.abs(class_shap_values).mean(axis=0),
        index=X.columns
    )

    # 3. --- THIS IS THE KEY CHANGE ---
    # Select the importance scores ONLY for your pre-selected genes
    importance_for_selected_genes = feature_importance_series.loc[genes_to_plot]

    # 4. Sort these values for a clean plot (most important at the top)
    sorted_importance = importance_for_selected_genes.sort_values(ascending=False)

    # 5. Calculate percentages based ONLY on the sum of these selected genes
    total_importance_selected = sorted_importance.sum()
    percentages = (sorted_importance / total_importance_selected) * 100

    # 6. Create the plot
    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.barh(sorted_importance.index, sorted_importance.values, color='steelblue')
    ax.invert_yaxis()

    # 7. Annotate each bar with its percentage
    for bar, percentage in zip(bars, percentages):
        ax.text(
            bar.get_width() + (total_importance_selected * 0.01),
            bar.get_y() + bar.get_height() / 2,
            f'{percentage:.2f}%',
            va='center',
            ha='left'
        )

    # --- Formatting ---
    ax.set_title(f'Top {len(genes_to_plot)} Curated Gene Importances for Class: "{class_name}"', fontsize=16)
    ax.set_xlabel('Mean Absolute SHAP Value', fontsize=12)
    plt.tight_layout()
    ax.set_xlim(right=ax.get_xlim()[1] * 1.15) # Make room for annotations

    plt.show()

# %% [markdown]
# #RF Depth = None, SHAP

# %%
print("--- Training Random Forest Classifier with RF Depth  = None ---")
rf_model_none = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1, max_depth=None)
rf_model_none.fit(X_train_scaled, y_train)

# Predictions and Probability Predictions
y_pred_rf_none = rf_model_none.predict(X_test_scaled)
y_proba_rf_none = rf_model_none.predict_proba(X_test_scaled)



##--------------------------------##

#SHAP

# Create SHAP explainer for Random Forest
explainer = shap.TreeExplainer(rf_model_none)

# Get SHAP values for the first 500 samples of X_test
# Use the scaled test data (X_test_scaled) which was used for training
shap_values_none = explainer.shap_values(X_test[:500])

print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of SHAP values: {shap_values_none.shape}")




# PREPROCESS


top_genes_per_class_RF_with_none = {}
N = 5 # Let's find the top 5 genes for each class

# Iterate through the classes (the third dimension of shap_values)
# shap_values shape: (samples, features, classes)
for i in range(shap_values_none.shape[2]):
    # Calculate the mean absolute SHAP value for each gene across all samples for the current class
    global_importance = np.mean(np.abs(shap_values_none[:, :, i]), axis=0)

    # Create a DataFrame for easy sorting
    importance_df = pd.DataFrame({
        'Gene': X.columns,
        'SHAP_Importance': global_importance
    })

    #  Filter out the sex-specific genes ---
    filtered_importance_df = importance_df[~importance_df['Gene'].isin(genes_to_exclude)]


    # Sort by importance and get the top N genes from the *filtered* list
    top_genes = filtered_importance_df.sort_values(by='SHAP_Importance', ascending=False).head(N)

    # Store the results using the actual class name
    class_name = class_names[i]
    top_genes_per_class_RF_with_none[class_name] = top_genes['Gene'].tolist()

# Print the top genes for all classes
print("Top 5 Tumor-Specific Genes per Class (Sex-Specific Genes Removed):")
for class_name, genes in top_genes_per_class_RF_with_none.items():
    print(f" {class_name}: {genes}")
# Out:
# --- Training Random Forest Classifier with RF Depth  = None ---
# Shape of X_test: (1774, 12838)
# Shape of SHAP values: (500, 12838, 32)
# Top 5 Tumor-Specific Genes per Class (Sex-Specific Genes Removed):
#  adrenocortical cancer: ['MTSS1L', 'ABCC11', 'KNDC1', 'DOCK1', 'KLK4']
#  bladder urothelial carcinoma: ['GATA3', 'KLF5', 'ARMCX6', 'LPAR5', 'RPL19P12']
#  brain lower grade glioma: ['ATP1B2', 'SOX8', 'TRIM9', 'APC2', 'FEZ1']
#  breast invasive carcinoma: ['NAT1', 'FSIP1', 'TRPS1', 'GATA3', 'PAX8']
#  cervical & endocervical cancer: ['IL1A', 'RFC4', 'ARHGAP6', 'PAQR6', 'PAX8']
#  cholangiocarcinoma: ['APC2', 'MAT1A', 'SLC17A3', 'PLG', 'SPEG']
#  colon adenocarcinoma: ['NAT1', 'SH3BGRL2', 'HOXA13', 'FSIP1', 'ICAM5']
#  diffuse large B-cell lymphoma: ['FUT1', 'KRT6B', 'PLG', 'APOC1', 'GEN1']
#  esophageal carcinoma: ['HIPK2', 'PDLIM5', 'RPPH1', 'CSDAP1', 'CYP2B6']
#  glioblastoma multiforme: ['FEZ1', 'ATP1B2', 'APC2', 'CSPG5', 'MTSS1L']
#  head & neck squamous cell carcinoma: ['ANXA2P1', 'PA2G4P4', 'CSDAP1', 'PLEKHF2', 'FEZ1']
#  kidney chromophobe: ['PAX8', 'ENPEP', 'GATA3', 'PLEKHJ1', 'TM4SF18']
#  kidney clear cell carcinoma: ['SLC3A1', 'ENPEP', 'FXYD2', 'PAX8', 'SLC28A1']
#  kidney papillary cell carcinoma: ['SLC3A1', 'FXYD2', 'ENPEP', 'SLC28A1', 'ENPP3']
#  liver hepatocellular carcinoma: ['MAT1A', 'SLC38A3', 'APOC1', 'F7', 'A1BG']
#  lung adenocarcinoma: ['SFTPA1', 'MBIP', 'STEAP2', 'XBP1', 'NAPSA']
#  lung squamous cell carcinoma: ['SFTPA1', 'KRT5', 'ENPEP', 'PRLR', 'MBIP']
#  mesothelioma: ['GFPT2', 'C8orf85', 'KIAA1370', 'UPK3B', 'PDLIM5']
#  ovarian serous cystadenocarcinoma: ['GJB5', 'ANKRD45', 'PLEKHF2', 'PCDHGC3', 'CYP4Z2P']
#  pancreatic adenocarcinoma: ['LOC400043', 'SLC3A1', 'PCSK9', 'SLC45A3', 'KIAA1324']
#  pheochromocytoma & paraganglioma: ['PCDHGC4', 'PTPRM', 'ATP1B2', 'ITGA3', 'SLC3A1']
#  prostate adenocarcinoma: ['SLC45A3', 'ZNF761', 'NKX3-1', 'PDLIM5', 'C15orf21']
#  rectum adenocarcinoma: ['TXNDC6', 'HNF4A', 'ZNF761', 'SATB2', 'PAX8']
#  sarcoma: ['APLNR', 'C14orf159', 'ENPEP', 'PA2G4P4', 'CSDAP1']
#  skin cutaneous melanoma: ['ARMCX6', 'PRLR', 'MMP25', 'PRAME', 'RPL19P12']
#  stomach adenocarcinoma: ['KRT5', 'ANXA2P1', 'C1orf114', 'CLRN3', 'LETM2']
#  testicular germ cell tumor: ['SUSD3', 'ANKS6', 'SLC28A1', 'RCC2', 'C15orf21']
#  thymoma: ['ZNF552', 'EFHD1', 'FOXA1', 'MGAT3', 'HNF1A']
#  thyroid carcinoma: ['TG', 'PAX8', 'CRYGN', 'IQCA1', 'AFF1']
#  uterine carcinosarcoma: ['PCDHGC3', 'KRT5', 'PRLR', 'GLRB', 'PAX8']
#  uterine corpus endometrioid carcinoma: ['PAX8', 'C21orf58', 'NAT1', 'SGOL2', 'MAL']
#  uveal melanoma: ['MYB', 'ACN9', 'ABCC11', 'EFHD1', 'MTSS1L']

# %%
for class_name, genes_to_plot in top_genes_per_class_RF_with_none.items():

    # Find the index 'i' corresponding to the current class_name
    # This is needed to slice the correct part of the shap_values array
    i = list(class_names).index(class_name)

    class_shap_values = shap_values_none[:, :, i]

    # We still need this to look up the values for our selected genes
    feature_importance_series = pd.Series(
        np.abs(class_shap_values).mean(axis=0),
        index=X.columns
    )


    # Select the importance scores ONLY for your pre-selected genes
    importance_for_selected_genes = feature_importance_series.loc[genes_to_plot]

    # Sort these values for a clean plot (most important at the top)
    sorted_importance = importance_for_selected_genes.sort_values(ascending=False)

    # Calculate percentages based ONLY on the sum of these selected genes
    total_importance_selected = sorted_importance.sum()
    percentages = (sorted_importance / total_importance_selected) * 100


    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.barh(sorted_importance.index, sorted_importance.values, color='steelblue')
    ax.invert_yaxis()


    for bar, percentage in zip(bars, percentages):
        ax.text(
            bar.get_width() + (total_importance_selected * 0.01),
            bar.get_y() + bar.get_height() / 2,
            f'{percentage:.2f}%',
            va='center',
            ha='left'
        )


    ax.set_title(f'Top {len(genes_to_plot)} Curated Gene Importances for Class: "{class_name}"', fontsize=16)
    ax.set_xlabel('Mean Absolute SHAP Value', fontsize=12)
    plt.tight_layout()
    ax.set_xlim(right=ax.get_xlim()[1] * 1.15)

    plt.show()
